# %% [markdown]
# ### K-Means Clustering
# - Particular range plot the Ebow method and find the number of qualified clusters.
# - kmeans.inertia_ is mathematical property in kmeans, is used to find the least cutting (qualified clusters)
# - then using the n_clusters, train and predict the KMeans
# - using the predicted category, make supervised dataset (cluster value will be target variable here) and pass it to team who doing the target marketing.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Mall_Customers.csv")

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first = True)

# %%
dataset
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  Genre_Male
# 0             1   19                  15                      39           1
# 1             2   21                  15                      81           1
# 2             3   20                  16                       6           0
# 3             4   23                  16                      77           0
# 4             5   31                  17                      40           0
# ..          ...  ...                 ...                     ...         ...
# 195         196   35                 120                      79           0
# 196         197   45                 126                      28           0
# 197         198   32                 126                      74           1
# 198         199   32                 137                      18           1
# 199         200   30                 137                      83           1
#
# [200 rows x 5 columns]

# %%
dataset.columns
# Out:
# Index(['CustomerID', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)',
#        'Genre_Male'],
#       dtype='object')

# %%
from sklearn.cluster import KMeans

list1 = []
for i in range(1, 11):
	kmeans = KMeans(n_clusters = i, init = "k-means++", random_state = 42)
	kmeans.fit(X)
	list1.append(kmeans.inertia_)

plt.plot(range(1, 11), list1)
plt.title("The Elbow Method")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.show()

# %%
X = dataset.iloc[:, [3,4]].values

# %%
print(X)
# Out:
# [[39  1]
#  [81  1]
#  [ 6  0]
#  [77  0]
#  [40  0]
#  [76  0]
#  [ 6  0]
#  [94  0]
#  [ 3  1]
#  [72  0]
#  [14  1]
#  [99  0]
#  [15  0]
#  [77  0]
#  [13  1]
#  [79  1]
#  [35  0]
#  [66  1]
#  [29  1]
#  [98  0]
#  [35  1]
#  [73  1]
#  [ 5  0]
#  [73  1]
#  [14  0]
#  [82  1]
#  [32  0]
#  [61  1]
#  [31  0]
#  [87  0]
#  [ 4  1]
#  [73  0]
#  [ 4  1]
#  [92  1]
#  [14  0]
#  [81  0]
#  [17  0]
#  [73  0]
#  [26  0]
#  [75  0]
#  [35  0]
#  [92  1]
#  [36  1]
#  [61  0]
#  [28  0]
#  [65  0]
#  [55  0]
#  [47  0]
#  [42  0]
#  [42  0]
#  [52  0]
#  [60  1]
#  [54  0]
#  [60  1]
#  [45  0]
#  [41  1]
#  [50  0]
#  [46  1]
#  [51  0]
#  [46  1]
#  [56  1]
#  [55  1]
#  [52  0]
#  [59  0]
#  [51  1]
#  [59  1]
#  [50  0]
#  [48  0]
#  [59  1]
#  [47  0]
#  [55  1]
#  [42  0]
#  [49  0]
#  [56  0]
#  [47  1]
#  [54  1]
#  [53  0]
#  [48  1]
#  [52  0]
#  [42  0]
#  [51  1]
#  [55  1]
#  [41  1]
#  [44  0]
#  [57  0]
#  [46  1]
#  [58  0]
#  [55  0]
#  [60  0]
#  [46  0]
# ...

# %% [markdown]
# ### Find the number of possible clusters using Elbow method

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init="k-means++", random_state=42)

# There is no need the fit and then predict. At the training time itself it will predict
y_kmeans = kmeans.fit_predict(X)

# %%
y_kmeans
# Out:
# array([4, 1, 0, 1, 4, 1, 0, 3, 0, 1, 0, 3, 0, 1, 0, 1, 4, 1, 4, 3, 4, 1,
#        0, 1, 0, 1, 4, 2, 4, 3, 0, 1, 0, 3, 0, 1, 0, 1, 4, 1, 4, 3, 4, 2,
#        4, 1, 2, 2, 4, 4, 2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 4, 2, 2, 2, 2,
#        2, 2, 2, 4, 2, 4, 4, 2, 2, 2, 4, 2, 4, 2, 2, 2, 2, 4, 2, 2, 4, 2,
#        2, 2, 4, 2, 2, 2, 4, 2, 4, 2, 2, 4, 2, 3, 4, 1, 4, 3, 0, 1, 0, 1,
#        4, 1, 0, 3, 0, 1, 0, 1, 0, 3, 4, 3, 0, 3, 4, 1, 0, 3, 0, 3, 0, 1,
#        0, 3, 0, 1, 0, 1, 4, 3, 0, 3, 4, 1, 0, 3, 4, 2, 0, 1, 0, 3, 0, 3,
#        0, 1, 0, 3, 4, 3, 0, 3, 4, 3, 0, 1, 0, 3, 0, 1, 0, 3, 0, 1, 4, 1,
#        0, 3])

# %%
supervised = pd.DataFrame(dataset)

supervised["Cluster_group"] = y_kmeans

# %%
supervised
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  Genre_Male  \
# 0             1   19                  15                      39           1
# 1             2   21                  15                      81           1
# 2             3   20                  16                       6           0
# 3             4   23                  16                      77           0
# 4             5   31                  17                      40           0
# ..          ...  ...                 ...                     ...         ...
# 195         196   35                 120                      79           0
# 196         197   45                 126                      28           0
# 197         198   32                 126                      74           1
# 198         199   32                 137                      18           1
# 199         200   30                 137                      83           1
#
#      Cluster_group
# 0                4
# ...

# %%
supervised.to_csv("marketing_dept.csv", index=False)

# %%
marketing_team_dataset = pd.read_csv("marketing_dept.csv")

# %%
marketing_team_dataset
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  Genre_Male  \
# 0             1   19                  15                      39           1
# 1             2   21                  15                      81           1
# 2             3   20                  16                       6           0
# 3             4   23                  16                      77           0
# 4             5   31                  17                      40           0
# ..          ...  ...                 ...                     ...         ...
# 195         196   35                 120                      79           0
# 196         197   45                 126                      28           0
# 197         198   32                 126                      74           1
# 198         199   32                 137                      18           1
# 199         200   30                 137                      83           1
#
#      Cluster_group
# 0                4
# ...

# %%
centroids = kmeans.cluster_centers_

# %%
centroids
# Out:
# array([[11.84615385,  0.56410256],
#        [74.25      ,  0.40625   ],
#        [52.79032258,  0.46774194],
#        [90.7037037 ,  0.44444444],
#        [37.        ,  0.3       ]])
